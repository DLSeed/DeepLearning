# %%
from pathlib import Path

repo_path = Path("/content/AudioSep")
if not repo_path.exists():
    # !git clone https://github.com/Audio-AGI/AudioSep.git

# %cd /content/AudioSep
# Out:
# Cloning into 'AudioSep'...
# remote: Enumerating objects: 202, done.
# remote: Counting objects: 100% (202/202), done.
# remote: Compressing objects: 100% (156/156), done.
# remote: Total 202 (delta 79), reused 131 (delta 38), pack-reused 0
# Receiving objects: 100% (202/202), 16.51 MiB | 17.98 MiB/s, done.
# Resolving deltas: 100% (79/79), done.
# /content/AudioSep

# %%
# !pip install torchlibrosa==0.1.0 gradio==3.47.1 gdown lightning transformers==4.28.1 ftfy braceexpand webdataset soundfile wget h5py
# Out:
# Collecting torchlibrosa==0.1.0
#   Downloading torchlibrosa-0.1.0-py3-none-any.whl (11 kB)
# Collecting gradio==3.47.1
#   Downloading gradio-3.47.1-py3-none-any.whl (20.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 46.1 MB/s eta 0:00:00
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Collecting lightning
#   Downloading lightning-2.1.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 58.3 MB/s eta 0:00:00
# Collecting transformers==4.28.1
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 75.1 MB/s eta 0:00:00
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.6 MB/s eta 0:00:00
# Collecting braceexpand
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Collecting webdataset
#   Downloading webdataset-0.2.62-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchlibrosa==0.1.0) (1.23.5)
# Requirement already satisfied: librosa>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from torchlibrosa==0.1.0) (0.10.1)
# Collecting aiofiles<24.0,>=22.0 (from gradio==3.47.1)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (4.2.2)
# Collecting fastapi (from gradio==3.47.1)
#   Downloading fastapi-0.104.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 10.8 MB/s eta 0:00:00
# Collecting ffmpy (from gradio==3.47.1)
#   Downloading ffmpy-0.3.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.6.0 (from gradio==3.47.1)
#   Downloading gradio_client-0.6.0-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.8/298.8 kB 29.4 MB/s eta 0:00:00
# Collecting httpx (from gradio==3.47.1)
#   Downloading httpx-0.25.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 10.0 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.14.0 (from gradio==3.47.1)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 21.9 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (6.1.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (3.7.1)
# Collecting orjson~=3.0 (from gradio==3.47.1)
#   Downloading orjson-3.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (9.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (1.10.13)
# Collecting pydub (from gradio==3.47.1)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart (from gradio==3.47.1)
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (6.0.1)
# Requirement already satisfied: requests~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (2.31.0)
# Collecting semantic-version~=2.0 (from gradio==3.47.1)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.47.1) (4.5.0)
# Collecting uvicorn>=0.14.0 (from gradio==3.47.1)
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 9.9 MB/s eta 0:00:00
# Collecting websockets<12.0,>=10.0 (from gradio==3.47.1)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.1) (3.12.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.1) (2023.6.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.28.1)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 105.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.1) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.6.0->gradio==3.47.1) (2023.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Collecting lightning-utilities<2.0,>=0.8.0 (from lightning)
#   Downloading lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: torch<4.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (2.1.0+cu118)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning)
#   Downloading torchmetrics-1.2.0-py3-none-any.whl (805 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.2/805.2 kB 70.6 MB/s eta 0:00:00
# Collecting pytorch-lightning (from lightning)
#   Downloading pytorch_lightning-2.1.0-py3-none-any.whl (774 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.6/774.6 kB 58.6 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy) (0.2.8)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile) (1.16.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.47.1) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.47.1) (4.19.1)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.47.1) (0.12.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec->gradio-client==0.6.0->gradio==3.47.1) (3.8.6)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (1.11.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (0.56.4)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (1.7.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.8.0->torchlibrosa==0.1.0) (1.0.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.47.1) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.47.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.47.1) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.47.1) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.47.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.47.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==3.47.1) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==3.47.1) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==3.47.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==3.47.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==3.47.1) (2023.7.22)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=1.12.0->lightning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=1.12.0->lightning) (3.1)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=1.12.0->lightning) (2.1.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio==3.47.1) (8.1.7)
# Collecting h11>=0.8 (from uvicorn>=0.14.0->gradio==3.47.1)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio==3.47.1) (3.7.1)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi->gradio==3.47.1)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 11.7 MB/s eta 0:00:00
# Collecting typing-extensions~=4.0 (from gradio==3.47.1)
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Collecting httpcore<0.19.0,>=0.18.0 (from httpx->gradio==3.47.1)
#   Downloading httpcore-0.18.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.47.1) (1.3.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==3.47.1) (1.7.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.6.0->gradio==3.47.1) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.6.0->gradio==3.47.1) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.6.0->gradio==3.47.1) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.6.0->gradio==3.47.1) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.6.0->gradio==3.47.1) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->gradio-client==0.6.0->gradio==3.47.1) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio==3.47.1) (1.1.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.47.1) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.47.1) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.47.1) (0.10.6)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa>=0.8.0->torchlibrosa==0.1.0) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa>=0.8.0->torchlibrosa==0.1.0) (67.7.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa>=0.8.0->torchlibrosa==0.1.0) (3.11.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa>=0.8.0->torchlibrosa==0.1.0) (3.2.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<4.0,>=1.12.0->lightning) (1.3.0)
# Building wheels for collected packages: wget, ffmpy
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=91f4f80c228991964033c7fd32fb4ef7f71038c86a44898ffab3dc81dbb26af4
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.1-py3-none-any.whl size=5579 sha256=0a7881465f7caa04511174a9254cc9ea427d1eaf6f1a4d490520142bd3b0a17e
#   Stored in directory: /root/.cache/pip/wheels/01/a6/d1/1c0828c304a4283b2c1639a09ad86f83d7c487ef34c6b4a1bf
# Successfully built wget ffmpy
# Installing collected packages: wget, tokenizers, pydub, ffmpy, braceexpand, websockets, webdataset, typing-extensions, semantic-version, python-multipart, orjson, h11, ftfy, aiofiles, uvicorn, starlette, lightning-utilities, huggingface-hub, httpcore, transformers, torchmetrics, httpx, fastapi, torchlibrosa, pytorch-lightning, gradio-client, lightning, gradio
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.8.0 which is incompatible.
# Successfully installed aiofiles-23.2.1 braceexpand-0.1.7 fastapi-0.104.0 ffmpy-0.3.1 ftfy-6.1.1 gradio-3.47.1 gradio-client-0.6.0 h11-0.14.0 httpcore-0.18.0 httpx-0.25.0 huggingface-hub-0.18.0 lightning-2.1.0 lightning-utilities-0.9.0 orjson-3.9.9 pydub-0.25.1 python-multipart-0.0.6 pytorch-lightning-2.1.0 semantic-version-2.10.0 starlette-0.27.0 tokenizers-0.13.3 torchlibrosa-0.1.0 torchmetrics-1.2.0 transformers-4.28.1 typing-extensions-4.8.0 uvicorn-0.23.2 webdataset-0.2.62 websockets-11.0.3 wget-3.2

# %%
checkpoints_dir = Path("checkpoint")
checkpoints_dir.mkdir(exist_ok=True)

models = (
    (
        "https://huggingface.co/spaces/badayvedat/AudioSep/resolve/main/checkpoint/audiosep_base_4M_steps.ckpt",
        checkpoints_dir / "audiosep_base_4M_steps.ckpt"
    ),
    (
        "https://huggingface.co/spaces/badayvedat/AudioSep/resolve/main/checkpoint/music_speech_audioset_epoch_15_esc_89.98.pt",
        checkpoints_dir / "music_speech_audioset_epoch_15_esc_89.98.pt"
    )
)

for model_url, model_path in models:
    if not model_path.exists():
        # !wget {model_url} -O {model_path}
# Out:
# --2023-10-21 15:40:07--  https://huggingface.co/spaces/badayvedat/AudioSep/resolve/main/checkpoint/audiosep_base_4M_steps.ckpt
# Resolving huggingface.co (huggingface.co)... 18.164.174.23, 18.164.174.55, 18.164.174.17, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.23|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/25/5f/255f11fd2743cf4de0c72f1eba5cdf82634d22af3ce4fcc5b16dbd7b7feddaca/f8cda01bfd0ebd141eef45d41db7a3ada23a56568465840d3cff04b8010ce82c?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27audiosep_base_4M_steps.ckpt%3B+filename%3D%22audiosep_base_4M_steps.ckpt%22%3B&Expires=1698162007&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=ZcfYoOMO%7ELADkTiMVGudamTyVntoprvDtCgELToh28iEb72CH-jXWw4n96FiV1lpHwskGAsX0StP8IYwuAKans02sHclAvWoE7QZhXO5P0JmYV7efXnvXrvQkCC5i5FLlGPA1CWVhP1aKnszWWQSAy0LjQSqtdwNAw76salyAoIWNWL5y2%7E2MqrHyz789L6%7ETWfZcQRg0XcD%7ECQLqd5ZJ5JdMKmfw5riipr3Jx83q6TVteuPQP8I7fsEZicCq2cn9XbjCi5aOEcjkh%7EtFq4i8xwN5nF4dYuHnWEDK%7EuyJ-aiPas1UY7ov5NYjBidWw9fMjOwaFdyfvQqTT1kHhKYRA__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-10-21 15:40:07--  https://cdn-lfs.huggingface.co/repos/25/5f/255f11fd2743cf4de0c72f1eba5cdf82634d22af3ce4fcc5b16dbd7b7feddaca/f8cda01bfd0ebd141eef45d41db7a3ada23a56568465840d3cff04b8010ce82c?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27audiosep_base_4M_steps.ckpt%3B+filename%3D%22audiosep_base_4M_steps.ckpt%22%3B&Expires=1698162007&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=ZcfYoOMO%7ELADkTiMVGudamTyVntoprvDtCgELToh28iEb72CH-jXWw4n96FiV1lpHwskGAsX0StP8IYwuAKans02sHclAvWoE7QZhXO5P0JmYV7efXnvXrvQkCC5i5FLlGPA1CWVhP1aKnszWWQSAy0LjQSqtdwNAw76salyAoIWNWL5y2%7E2MqrHyz789L6%7ETWfZcQRg0XcD%7ECQLqd5ZJ5JdMKmfw5riipr3Jx83q6TVteuPQP8I7fsEZicCq2cn9XbjCi5aOEcjkh%7EtFq4i8xwN5nF4dYuHnWEDK%7EuyJ-aiPas1UY7ov5NYjBidWw9fMjOwaFdyfvQqTT1kHhKYRA__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.65.25.40, 18.65.25.124, 18.65.25.122, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.65.25.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1264844076 (1.2G) [application/zip]
# Saving to: ‘checkpoint/audiosep_base_4M_steps.ckpt’
#
# checkpoint/audiosep 100%[===================>]   1.18G   116MB/s    in 8.7s
#
# 2023-10-21 15:40:16 (139 MB/s) - ‘checkpoint/audiosep_base_4M_steps.ckpt’ saved [1264844076/1264844076]
#
# --2023-10-21 15:40:16--  https://huggingface.co/spaces/badayvedat/AudioSep/resolve/main/checkpoint/music_speech_audioset_epoch_15_esc_89.98.pt
# Resolving huggingface.co (huggingface.co)... 18.164.174.23, 18.164.174.55, 18.164.174.17, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.23|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/25/5f/255f11fd2743cf4de0c72f1eba5cdf82634d22af3ce4fcc5b16dbd7b7feddaca/51c68f12f9d7ea25fdaaccf741ec7f81e93ee594455410f3bca4f47f88d8e006?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27music_speech_audioset_epoch_15_esc_89.98.pt%3B+filename%3D%22music_speech_audioset_epoch_15_esc_89.98.pt%22%3B&Expires=1698162016&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=laMv2kP5RNW45AvpBjrxaB8QL0dP8Ycm9dGe4blWEwhxMN8Z5SZ7a70tayFlqza9lGTcQpGdUQswhGkCvh8pBQQ1FcQqNONgomZQIN9Jb%7EsBrwQaa8pePSuXKDg8cO46kAIdazz0dWJ7pAXO976d83WAQLFiKga3a3DcdFuGnWku8bhN5M4WIa0XW10%7EZ36nmdjiUXwWun9cIokvFPG%7EsEL00-vSRxi%7Eq5UUR5yZxftEgxwB%7E451UUAjTUO4-wGrgQ9fulXPbssUnadpqFPHjppC-DyGIyEdLKAKBUKtmbj1MMCP-pSE0T4aW0pIeHVfkyKyHbgyYDl%7EAFfFQwD0zg__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-10-21 15:40:16--  https://cdn-lfs.huggingface.co/repos/25/5f/255f11fd2743cf4de0c72f1eba5cdf82634d22af3ce4fcc5b16dbd7b7feddaca/51c68f12f9d7ea25fdaaccf741ec7f81e93ee594455410f3bca4f47f88d8e006?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27music_speech_audioset_epoch_15_esc_89.98.pt%3B+filename%3D%22music_speech_audioset_epoch_15_esc_89.98.pt%22%3B&Expires=1698162016&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=laMv2kP5RNW45AvpBjrxaB8QL0dP8Ycm9dGe4blWEwhxMN8Z5SZ7a70tayFlqza9lGTcQpGdUQswhGkCvh8pBQQ1FcQqNONgomZQIN9Jb%7EsBrwQaa8pePSuXKDg8cO46kAIdazz0dWJ7pAXO976d83WAQLFiKga3a3DcdFuGnWku8bhN5M4WIa0XW10%7EZ36nmdjiUXwWun9cIokvFPG%7EsEL00-vSRxi%7Eq5UUR5yZxftEgxwB%7E451UUAjTUO4-wGrgQ9fulXPbssUnadpqFPHjppC-DyGIyEdLKAKBUKtmbj1MMCP-pSE0T4aW0pIeHVfkyKyHbgyYDl%7EAFfFQwD0zg__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.65.25.40, 18.65.25.124, 18.65.25.122, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.65.25.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2352471003 (2.2G) [application/zip]
# Saving to: ‘checkpoint/music_speech_audioset_epoch_15_esc_89.98.pt’
#
# checkpoint/music_sp 100%[===================>]   2.19G  80.2MB/s    in 20s
#
# 2023-10-21 15:40:36 (111 MB/s) - ‘checkpoint/music_speech_audioset_epoch_15_esc_89.98.pt’ saved [2352471003/2352471003]

# %%
# !wget "https://audio-agi.github.io/Separate-Anything-You-Describe/demos/exp31_water drops_mixture.wav"
# Out:
# --2023-10-21 15:40:40--  https://audio-agi.github.io/Separate-Anything-You-Describe/demos/exp31_water%20drops_mixture.wav
# Resolving audio-agi.github.io (audio-agi.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to audio-agi.github.io (audio-agi.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 320044 (313K) [audio/wav]
# Saving to: ‘exp31_water drops_mixture.wav’
#
# exp31_water drops_m 100%[===================>] 312.54K  --.-KB/s    in 0.03s
#
# 2023-10-21 15:40:40 (9.96 MB/s) - ‘exp31_water drops_mixture.wav’ saved [320044/320044]

# %%
import torch
from pipeline import build_audiosep, inference

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = build_audiosep(
      config_yaml='config/audiosep_base.yaml',
      checkpoint_path=str(models[0][1]),
      device=device)

audio_file = 'exp31_water drops_mixture.wav'
text = 'water drops'
output_file='separated_audio.wav'

# AudioSep processes the audio at 32 kHz sampling rate
inference(model, audio_file, text, output_file, device)
# Out:
# (…).co/roberta-base/resolve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# (…).co/roberta-base/resolve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# (…)co/roberta-base/resolve/main/config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Load AudioSep model from [checkpoint/audiosep_base_4M_steps.ckpt]
# Separate audio from [exp31_water drops_mixture.wav] with textual query [water drops]
# Write separated audio to [separated_audio.wav]

# %%
print(f"The separated audio is saved to: '{output_file}' file.")
# Out:
# The separated audio is saved to: 'separated_audio.wav' file.

# %%
import torch
from pipeline import build_audiosep, inference

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = build_audiosep(
      config_yaml='config/audiosep_base.yaml',
      checkpoint_path=str(models[0][1]),
      device=device)

audio_file = 'HOYO-MiX_-_Da_Capo-Part.wav'
text = 'human voice'
output_file='Da_Capo_separated_audio.wav'

# AudioSep processes the audio at 32 kHz sampling rate
inference(model, audio_file, text, output_file, device)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Load AudioSep model from [checkpoint/audiosep_base_4M_steps.ckpt]
# Separate audio from [HOYO-MiX_-_Da_Capo-Part.wav] with textual query [human voice]
# Write separated audio to [Da_Capo_separated_audio.wav]

# %%
print(f"The separated audio is saved to: '{output_file}' file.")
# Out:
# The separated audio is saved to: 'Da_Capo_separated_audio.wav' file.
