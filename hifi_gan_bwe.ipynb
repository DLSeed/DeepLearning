# %% [markdown]
# <a href="https://colab.research.google.com/github/DLSeed/DeepLearning/blob/main/hifi_gan_bwe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %%
# !pip install --upgrade hifi-gan-bwe

# %%
import audioread
import google.colab.files
import numpy as np
import torch
from IPython.display import Audio
from hifi_gan_bwe import BandwidthExtender

# %% [markdown]
# ## Load Pretrained Model

# %%
model = BandwidthExtender.from_pretrained("hifi-gan-bwe-10-42890e3-vctk-48kHz")

# %% [markdown]
# ## Upload an Audio File to Extend

# %%
path = next(iter(google.colab.files.upload().keys()))
# Out:
#      <input type="file" id="files-8e31bf5f-8425-4c31-8208-cb84fead2443" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8e31bf5f-8425-4c31-8208-cb84fead2443">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving beachmouse8kHz.wav to beachmouse8kHz (4).wav

# %%
with audioread.audio_open(path) as input_:
    sample_rate = input_.samplerate
    x = (
        np.hstack([np.frombuffer(b, dtype=np.int16) for b in input_])
        .reshape([-1, input_.channels])
        .astype(np.float32)
        / 32767.0
    )

Audio(x.T, rate=sample_rate, autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Run the Model

# %%
with torch.no_grad():
    y = np.stack([model(torch.from_numpy(x), sample_rate) for x in x.T]).T

Audio(y.T, rate=int(model.sample_rate), autoplay=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3635: UserWarning: Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
